# %% [markdown]
# ## Requirements

# %%
# !pip install synapseclient

# %% [markdown]
# ## Import

# %%
import shutil

# %%
MASTER_TOKEN = "eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..u-JjpicHKmSQiaQ42yGpOz4r9z8AgW0kCcP9xb7Bo36p8vjrUEZszSPkod9qlAlzBawGstVOOqcCFF8yj1beKzIxcC5K7C0vrHlvVXhqL4SdjfMw2vwb2_Yf7W6Jt1rHtxyZeW52nHnNoc1eAy2BVI_xcZIosN4oLuI9yfukemMJ09Zy4N_O8du-Ids0kvAN-ZE-PjzGr1XY9atIlwrKbuIJFY8I5B_W2L4fvpokN-qAuTNLUtQ9hLbosVuTjBFA9GF9MazulQFoSFdW7TUlsNVFiv4l56XmMgjmG4NugXEZbRmIvJ-_8iYDG4zN22AXe6ZFNG94bxypvinM4ZLWdQ"

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# %%
# Specify the folder path in your Google Drive
# Replace 'My Drive/Your_Folder_Name' with the actual path to your desired folder
drive_folder = '/content/drive/MyDrive/SAND 🗣️​/VOC-ALS Database'

# Create the folder if it doesn't exist
os.makedirs(drive_folder, exist_ok=True)

# %%
 import synapseclient
 import synapseutils

 syn = synapseclient.Synapse()
 syn.login(authToken=MASTER_TOKEN)
# Out:
# Welcome, Toio!
# INFO:synapseclient_default:Welcome, Toio!

# %%
def copy_file_to_destination(file_to_save, subfolder):
  # Assuming 'files' is the list of downloaded Synapse files and the first element is the one you want
  # The file path in the cache is available in file_info.path
  source_path = file_to_save.path
  filename = file_to_save.name # Get the original filename with extension

  # Construct the destination path in Google Drive
  drive_subfolder = f"{drive_folder}/{subfolder}"
  os.makedirs(drive_subfolder, exist_ok=True)
  destination_path = os.path.join(drive_subfolder, filename)

  # Copy the file from the Synapse cache to Google Drive
  shutil.copy(source_path, destination_path)

  print(f"File '{filename}' copied to: {destination_path}")

# %%
FILE_MAP = {
    "phonationA":"syn53174987",
    "phonationE":"syn53175169",
    "phonationI":"syn53175354",
    "phonationO":"syn53175548",
    "phonationU":"syn53175731",
    "rhythmKA":"syn53175914",
    "rhythmPA":"syn53176264",
    "rhythmTA":"syn53176762"
}

# %%
for subfolder, id in FILE_MAP.items():
  files = synapseutils.syncFromSynapse(syn, id)
  for file in files:
    copy_file_to_destination(file, subfolder)
# Out:
# ...
# [syn53174987:phonationA]: Syncing Folder from Synapse.
# INFO:synapseclient_default:[syn53174987:phonationA]: Syncing Folder from Synapse.
# ...
# [syn53174990:CT001_phonationA.wav]: Found existing file at /root/.synapseCache/741/131674741/CT001_phonationA.wav, skipping download.
# INFO:synapseclient_default:[syn53174990:CT001_phonationA.wav]: Found existing file at /root/.synapseCache/741/131674741/CT001_phonationA.wav, skipping download.
# ...
# [syn53174991:CT004_phonationA.wav]: Found existing file at /root/.synapseCache/742/131674742/CT004_phonationA.wav, skipping download.
# INFO:synapseclient_default:[syn53174991:CT004_phonationA.wav]: Found existing file at /root/.synapseCache/742/131674742/CT004_phonationA.wav, skipping download.
# ...
# [syn53174993:CT010_phonationA.wav]: Found existing file at /root/.synapseCache/744/131674744/CT010_phonationA.wav, skipping download.
# ...
